# %% [markdown]
# # 🕵️‍♀️ Kryptologie – Historische Chiffriersysteme
# **Name:**
# **Datum:**
#
# ---
#
# ## 🧭 Anleitung
#
# In diesem Notizbuch dokumentierst du **deine Arbeit mit inf-schule.de** zum Thema **Kryptologie – Historische Chiffriersysteme**
#
# **Ziel:**
# Du sollst verstehen, wie sich Verschlüsselungsverfahren im Lauf der Zeit verbessert haben – und warum einfache Verfahren wie Cäsar nicht ausreichen.
#
# **Ablauf:**
# 1. Lies dir die Kapitel auf inf-schule.de in deinem eigenen Tempo durch.
# 2. Führe die interaktiven Aufgaben und Überlegungen dort selbstständig durch.
# 3. Notiere deine Ergebnisse, Erkenntnisse und Gedanken hier im Notizbuch.
# 4. Am Ende jeder Stunde trägst du unten eine **kurze Reflexion** zu deinem Lernerfolg ein.
#
# **Hinweise:**
# - Du kannst Text, Überschriften, Listen und Bilder einfügen.
# - Nutze Markdown-Formatierung (`#`, `**fett**`, `- Listenpunkt`) für Übersichtlichkeit.
# - Arbeite so, dass jemand anderes deine Notizen verstehen würde.
# - Ich (Herr Thon) kann in deinem Notizbuch Kommentare ergänzen oder Feedback geben.
#
# ---
#
# ## 📅 Reflexion pro Stunde
#
# Fülle diesen Abschnitt **am Ende jeder Arbeitsstunde** aus.
#
# **Heute habe ich gelernt, dass ...**
# **Das war schwierig:**
# **Das hat mir geholfen:**
# **Meine offene Frage ist:**
#
# ---
#
# ## ✅ Abschlusstest (Hinweis)
#
# Wenn du alle Kapitel bearbeitet hast, findest du in Moodle einen **kurzen Test**.
# Er prüft, ob du die Verfahren verstanden hast und deren Schwächen erklären kannst.

# %% [markdown]
# ## Notizen vom 20.11.2025
#
# ### Station - Chiffrierung mit dem Verschiebeverfahren
#
# Aufgabe 1: ...
#
# ...
#
# ...
#
# ### Reflexion
#
# **Heute habe ich gelernt, dass ...**
# **Das war schwierig:**
# **Das hat mir geholfen:**
# **Meine offene Frage ist:**
