# %% [markdown]
# # 🔐 Kryptologie – Moderne Chiffriersysteme
# **Name:**
# **Datum:**
#
# ---
#
# ## 🧭 Anleitung
#
# In diesem Notizbuch dokumentierst du **deine Arbeit mit inf-schule.de** zum Thema **Kryptologie – Moderne Chiffriersysteme**
# 👉 [https://inf-schule.de/kryptologie/modernechiffriersysteme](https://inf-schule.de/kryptologie/modernechiffriersysteme)
#
# **Ziel:**
# Du sollst verstehen, wie moderne Verfahren die Schwächen der historischen Chiffren überwinden.
# Du lernst, was heute nötig ist, um digitale Kommunikation sicher zu machen (z. B. mit Computern, Schlüsselpaaren und Zertifikaten).
#
# **Ablauf:**
# 1. Lies die Kapitel auf inf-schule.de sorgfältig durch.
# 2. Führe die interaktiven Aufgaben selbstständig aus.
# 3. Notiere deine Erkenntnisse, Beobachtungen und Fragen hier.
# 4. Am Ende jeder Stunde füllst du den Abschnitt **Reflexion** aus.
#
# **Hinweise:**
# - Du kannst Text, Überschriften, Tabellen oder Skizzen (z. B. mit `![](bild.png)`) einfügen.
# - Verwende Markdown-Formatierung (`#`, `**fett**`, `- Liste`) für Übersichtlichkeit.
# - Arbeite so, dass auch andere deine Notizen nachvollziehen können.
# - Ich (Herr Thon) kann direkt im Notizbuch Kommentare ergänzen.
#
# ---
#
# ## 📘 Themenüberblick
#
# Die Kapitel auf inf-schule.de behandeln mehrere moderne Verfahren. Nutze die folgenden Abschnitte, um deine wichtigsten Erkenntnisse festzuhalten.

# %% [markdown]
# ## 🔑 1. Symmetrische Verschlüsselung
#
# **Beispiel:** AES, DES
#
# **Notizen:**
# - Was bedeutet *symmetrisch* in diesem Zusammenhang?
# - Welche Vorteile und Nachteile hat diese Methode?
# - Warum ist der Schlüsselaustausch ein Problem?
#
# ---

# %% [markdown]
# ## 🧮 2. Asymmetrische Verschlüsselung
#
# **Beispiel:** RSA, Public-Key-Kryptographie
#
# **Notizen:**
# - Was unterscheidet asymmetrische von symmetrischer Verschlüsselung?
# - Wie funktionieren *öffentlicher* und *privater* Schlüssel?
# - Warum ist dieses Verfahren sicher, obwohl der öffentliche Schlüssel bekannt ist?
# - Welche Rolle spielen große Zahlen und Primfaktoren?
#
# ---

# %% [markdown]
# ## ⚙️ 3. Hybride Verfahren
#
# **Beispiel:** HTTPS, E-Mail-Verschlüsselung
#
# **Notizen:**
# - Wie kombinieren hybride Systeme symmetrische und asymmetrische Verfahren?
# - Warum ist das in der Praxis sinnvoll?
# - Was passiert, wenn der private Schlüssel gestohlen wird?
# - Welche Sicherheitsziele werden hier besonders berücksichtigt? (Vertraulichkeit, Integrität, Authentizität)
#
# ---

# %% [markdown]
# ## 🧾 4. Digitale Signaturen und Authentifizierung
#
# **Beispiel:** Zertifikate, elektronische Unterschrift
#
# **Notizen:**
# - Wie kann man sicherstellen, dass eine Nachricht wirklich vom Absender stammt?
# - Was ist eine digitale Signatur?
# - Welche Rolle spielen Zertifikate (z. B. bei Webseiten)?
#
# ---

# %% [markdown]
# ## 📊 5. Vergleich der modernen Verfahren
#
# | Verfahren | Schlüsselart | Beispiel | Vorteil | Nachteil |
# |------------|---------------|-----------|----------|-----------|
# | Symmetrisch | gemeinsamer Schlüssel | AES | schnell | Schlüsselverteilung schwierig |
# | Asymmetrisch | Schlüsselpaar | RSA | sicherer Austausch | rechenintensiv |
# | Hybrid | Kombination | HTTPS | praktisch, sicher | technisch komplex |
#
# Ergänze ggf. weitere Verfahren oder Erkenntnisse.
#
# ---

# %% [markdown]
# ## 📅 Reflexion pro Stunde
#
# Fülle diesen Abschnitt **am Ende jeder Arbeitsstunde** aus.
#
# **Heute habe ich gelernt, dass ...**
# **Das war schwierig:**
# **Das hat mir geholfen:**
# **Meine offene Frage ist:**
#
# ---
#
# ## ✅ Abschlusstest (Hinweis)
#
# Wenn du alle Kapitel bearbeitet hast, findest du in Moodle einen **Test zu modernen Chiffriersystemen**.
# Er prüft, ob du die Unterschiede zwischen symmetrischen, asymmetrischen und hybriden Verfahren erklären kannst und weißt, wozu man digitale Signaturen braucht.
