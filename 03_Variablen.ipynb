# %% [markdown]
# # Einführung in Python: Variablen & Eingaben
#
# In diesem Notebook lernen wir die Grundlagen, um später unsere eigene Verschlüsselungs-Maschine zu bauen.
# Wir nutzen dieses Dokument als **interaktiven Notizblock**.
#
# **Ziele:**
# * Verstehen, was Variablen sind
# * Daten im Computer speichern
# * Den Unterschied zwischen Text und Zahlen verstehen

# %% [markdown]
# ## 1. Was ist eine Variable?
#
# Stell dir eine Variable vor wie einen **Karton** in einem Lagerhaus.
# * Der Karton hat einen **Namen** (Beschriftung außen).
# * Im Karton ist ein **Inhalt** (Wert).
#
# In Python erstellen wir so einen „Karton“ mit einem `Gleich`-Zeichen:

# %%
# Wir erstellen eine Variable für eine Nachricht
# TODO: Gemeinsam ausfüllen

# Der Text „Hallo Welt“ wird in die Box „nachricht“ gepackt

# Wie schauen wir in den Karton?
# Out:
# Hallo Welt

# %% [markdown]
# ### Mini-Aufgabe
#
# Erstelle in der Zelle unten eine Variable mit dem Namen `mein_name` und speichere deinen Vornamen darin.
# Lass ihn anschließend mit `print()` anzeigen.

# %%
# Dein Code hier:

# %% [markdown]
# ## 2. Text vs. Zahlen (Die „Caesar-Falle“)
#
# Für den Computer ist es ein riesiger Unterschied, ob wir mit Wörtern oder Zahlen arbeiten.
# Beim Cäsar-Verfahren ist das wichtig, weil wir Buchstaben (Text) haben, aber mit einer Verschiebung (Zahl) rechnen.
#
# * `String` (str): Text, muss immer in Anführungszeichen stehen `""` oder `''`.
# * `Integer` (int): Ganze Zahlen, stehen ohne Anführungszeichen.

# %%
# Wir probieren aus, was passiert, wenn man Text und Zahl mischt:

verschiebung = 3       # Das ist eine Zahl (int)
buchstabe = "A"        # Das ist Text (str)
falsche_zahl = "3"     # ACHTUNG: Das sieht aus wie eine Zahl, ist aber Text!

# Experiment 1: Zahl + Zahl
# print(verschiebung + 5)

# Experiment 2: Text + Text
# print(buchstabe + "B")

# Experiment 3: Was passiert hier? (Live ausprobieren und Fehler analysieren)
# print(buchstabe + verschiebung)

# %% [markdown]
# ## 3. Mit dem Benutzer sprechen (`input`)
#
# Programme sind langweilig, wenn sie immer das Gleiche tun. Wir wollen, dass der Benutzer etwas eingeben kann.
# Dazu nutzen wir den Befehl `input()`.
#
# **WICHTIG:** Alles, was aus `input()` kommt, ist für Python erst einmal immer **TEXT** (String). Auch wenn du eine Zahl eintippst!

# %%
# Wir fragen den Benutzer nach einer Geheimbotschaft

geheimnis = input("Bitte gib deine Nachricht ein: ")

print("Du hast eingegeben:")
print(geheimnis)
# Out:
# Bitte gib deine Nachricht ein:  Test
# Du hast eingegeben:
# Test

# %%
# Problem: Wenn wir nach der Verschiebung fragen, brauchen wir eine Zahl zum Rechnen.
# Wir müssen den Text also in eine Zahl umwandeln -> int()

# TODO: Live Code vervollständigen

eingabe = input("Wie weit soll verschoben werden? ")
schluessel =   # Hier verwandeln wir den Text "3" in die Zahl 3

# Jetzt können wir rechnen:
ergebnis =
print("Wenn wir 10 addieren, erhalten wir:", ergebnis)
